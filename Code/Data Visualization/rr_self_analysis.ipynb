# %% [markdown]
# # PDAC LP (Inexact) Algorithm Analysis
# This notebook is used to analyze the performance of the relaxed ILP (inexact) job scheduling algorithm. Specifically, it uses a greedy heuristic scheduling algorithm and a naive scheduling algorithm for comparison. The peak demand above the curve (PDAC) is measured across five different trials for each specified job batch size and then plotted on a graph.

# %%
import sys
import os
import random
import json
import matplotlib.pyplot as plt
import numpy as np
import time
import csv

# Add the parent directory of AAC/ to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %% [markdown]
# Import the relaxed ILP, greedy and naive algorithms from their respective files in the repository

# %%
from PDAC.pdac_scheduling_lp import solve_pdac_lp
from PDAC.pdac_scheduling_greedy import solve_pdac_greedy
from PDAC.pdac_scheduling_naive import solve_pdac_naive

# %% [markdown]
# # Program Parameters
# In the code below, you can specify the start time, end time and maximum length of each job in each batch of jobs. \
# \
# &emsp;&emsp; - 0 denotes 12am and 1400 denotes 12am of the following day. \
# &emsp;&emsp; - Therefore, one day contains exactly 1440 minutes of job data
# \
# \
# Additionally, you can specify the sizes of each job batch that is analyzed in this program. \
# \
# &emsp;&emsp; - The start size is the smallest batch size to be analyzed \
# &emsp;&emsp; - The end size is the largest batch size (exclusive) to be analyzed \
# &emsp;&emsp; - The step size is how much the job batch increases per analytical trial

# %%
start_time = 0
end_time = 1400
max_length = 700

start_size = 500
end_size = 1200
step_size = 100

analysis_num = 50

# %% [markdown]
# # Resource Curve
# The resource curve is represented by a list of values across the specified time period. Where at a given time t there will be exactly resources[t] amount of power available to the jobs. The data for these resources is available in the Input_Data folder.
# \
# \
# Additionally, each height is multiplied by a scaling factor. This is so that the resource curve better fits the job curve. Otherwise, the resource curve would be too small for any sort of significant analysis. This scaling factor remains constant for each of the trials and for every job batch size for the sake of consistency.

# %%
# Instantiate the resource curve
path = "../../Input_Data/resource_data.json"
with open(path, 'r') as file:
    data = json.load(file)

wind_energy = data['series'][1]['data']
solar_energy = data['series'][2]['data']
hydro_energy = data['series'][3]['data']

# Have 165 hours and you want minute by minute resolution. Therefore the total length of this list needs to be 165 * 60 in length
# The first 60 values of the list need to equal 0, the next need to equal 1. Therefore, i // 60
wind_energy_7_days = [0 for _ in range(165 * 60)]
for i in range(len(wind_energy_7_days)):
    wind_energy_7_days[i] = wind_energy[ i // 60 ]['value']

solar_energy_7_days = [0 for _ in range(165 * 60)]
for i in range(len(solar_energy_7_days)):
    solar_energy_7_days[i] = solar_energy[ i // 60 ]['value']

hydro_energy_7_days = [0 for _ in range(165 * 60)]
for i in range(len(hydro_energy_7_days)):
    hydro_energy_7_days[i] = hydro_energy[ i // 60 ]['value']


total = []
for i in range(165 * 60):
    total_sum = wind_energy_7_days[i] + solar_energy_7_days[i] + hydro_energy_7_days[i]
    total.append(total_sum)

day = 3
resources = total[(24 * day) + start_time : (24 * day) + end_time]

# # Implement a resource curve scaling factor to better fit the jobs
scale_factor = 4.233
resources = [r * scale_factor for r in resources]

# %% [markdown]
# # Algorithm Analysis
# For each batch size, there will be five trials run on each algorithm. Each time, a random assortment of jobs will be provided to the algorithms. However, these jobs will be the same for each algorithm, so they will be tested on the same jobs. This is for the most accurate possible comparisons.
# \
# \
# Additionally, the time it takes for each algorihtm to run is measured.

# %%
# This is The list of job objects that will be scheduled
# They each have a release, deadline, duration and height
path = "../../Input_Data/job_data.json"
with open(path, 'r') as file:
    data = json.load(file)

# Randomly shuffle the jobs so that there is variation between trials
jobs_array = data['jobs']

pdac_inexact = []
pdac_greedy = []
pdac_naive = []

final_data = []

trials = analysis_num

random.shuffle(jobs_array)

for batch_size in range(start_size, end_size, step_size):
    inexact_total = 0
    inexact_copy_total = 0
    greedy_total = 0
    naive_total = 0

    print(f"\nBatch Size: {batch_size}")

    for trial in range(trials):
        print(f"Trial #: {trial}")

        start = time.time()
        inexact = solve_pdac_lp(jobs_array, resources, start_time, end_time, max_length, batch_size)[0]
        end = time.time()
        inexact_total += inexact
        inexact_time = end - start
        print(f"Inexact Objective: {inexact}, Elapsed Time: {(end - start):.6f}")


        trial_data = {
            "batch size": batch_size, 
            "trial #": trial,
            "Rand_Round": inexact, 
            "Rand_Round Time": inexact_time, 
        }
        final_data.append(trial_data)

    pdac_inexact.append(inexact_total / trials)
    pdac_greedy.append(greedy_total / trials)
    pdac_naive.append(naive_total / trials)
# Out:
# Batch Size: 500
# Trial #: 0
# Inexact Objective: 6365.185999999991, Elapsed Time: 7.933730
# Trial #: 1
# Inexact Objective: 6429.075999999986, Elapsed Time: 7.638372
# Trial #: 2
# Inexact Objective: 6669.076999999994, Elapsed Time: 7.806126
# Trial #: 3
# Inexact Objective: 4390.626999999997, Elapsed Time: 7.772077
# Trial #: 4
# Inexact Objective: 7655.405999999988, Elapsed Time: 7.676637
# Trial #: 5
# Inexact Objective: 10049.701999999987, Elapsed Time: 7.773824
# Trial #: 6
# Inexact Objective: 6081.016999999993, Elapsed Time: 7.923630
# Trial #: 7
# Inexact Objective: 5867.9749999999985, Elapsed Time: 7.798224
# Trial #: 8
# Inexact Objective: 7021.197, Elapsed Time: 8.066423
# Trial #: 9
# Inexact Objective: 5264.346999999994, Elapsed Time: 7.721550
# Trial #: 10
# Inexact Objective: 6570.797000000002, Elapsed Time: 8.443340
# Trial #: 11
# Inexact Objective: 10049.701999999987, Elapsed Time: 7.887380
# Trial #: 12
# Inexact Objective: 8051.155999999992, Elapsed Time: 7.853309
# Trial #: 13
# Inexact Objective: 5129.565999999984, Elapsed Time: 9.442898
# Trial #: 14
# Inexact Objective: 6923.771999999994, Elapsed Time: 8.384199
# Trial #: 15
# Inexact Objective: 5570.716999999997, Elapsed Time: 8.034555
# Trial #: 16
# Inexact Objective: 4665.3369999999995, Elapsed Time: 7.773865
# Trial #: 17
# Inexact Objective: 5987.875999999993, Elapsed Time: 9.452477
# Trial #: 18
# Inexact Objective: 5244.921999999988, Elapsed Time: 8.499204
# Trial #: 19
# Inexact Objective: 5125.716999999997, Elapsed Time: 8.189640
# Trial #: 20
# Inexact Objective: 8471.326999999994, Elapsed Time: 8.209064
# Trial #: 21
# Inexact Objective: 6518.885000000002, Elapsed Time: 8.085659
# Trial #: 22
# Inexact Objective: 5743.945, Elapsed Time: 7.956911
# Trial #: 23
# Inexact Objective: 5264.346999999994, Elapsed Time: 7.776736
# Trial #: 24
# Inexact Objective: 5417.124999999993, Elapsed Time: 8.022203
# Trial #: 25
# Inexact Objective: 5129.565999999984, Elapsed Time: 7.772704
# Trial #: 26
# Inexact Objective: 8950.661999999986, Elapsed Time: 8.318715
# Trial #: 27
# Inexact Objective: 6523.651999999991, Elapsed Time: 8.311821
# Trial #: 28
# Inexact Objective: 5866.16599999999, Elapsed Time: 7.818233
# Trial #: 29
# Inexact Objective: 8693.021999999979, Elapsed Time: 8.079671
# Trial #: 30
# Inexact Objective: 6682.044999999991, Elapsed Time: 7.822429
# Trial #: 31
# Inexact Objective: 10049.701999999987, Elapsed Time: 8.120816
# Trial #: 32
# Inexact Objective: 5687.11199999999, Elapsed Time: 9.019030
# Trial #: 33
# Inexact Objective: 5720.731999999993, Elapsed Time: 8.790446
# Trial #: 34
# Inexact Objective: 6081.016999999993, Elapsed Time: 7.737938
# Trial #: 35
# Inexact Objective: 6556.581999999984, Elapsed Time: 7.966034
# Trial #: 36
# Inexact Objective: 6247.536999999997, Elapsed Time: 7.382100
# Trial #: 37
# Inexact Objective: 6030.733999999997, Elapsed Time: 7.772719
# Trial #: 38
# Inexact Objective: 9472.251999999997, Elapsed Time: 8.288264
# Trial #: 39
# Inexact Objective: 6264.561999999987, Elapsed Time: 8.444112
# Trial #: 40
# Inexact Objective: 6201.125999999997, Elapsed Time: 7.833242
# Trial #: 41
# Inexact Objective: 7050.786999999997, Elapsed Time: 7.893779
# Trial #: 42
# Inexact Objective: 5109.866999999995, Elapsed Time: 8.216815
# Trial #: 43
# Inexact Objective: 7159.705999999987, Elapsed Time: 8.243116
# Trial #: 44
# Inexact Objective: 8203.271999999986, Elapsed Time: 8.030772
# Trial #: 45
# Inexact Objective: 8185.43199999999, Elapsed Time: 7.862956
# Trial #: 46
# Inexact Objective: 8003.851999999988, Elapsed Time: 7.731224
# Trial #: 47
# Inexact Objective: 6557.744999999995, Elapsed Time: 8.115425
# Trial #: 48
# Inexact Objective: 6199.784999999996, Elapsed Time: 8.284392
# Trial #: 49
# Inexact Objective: 4896.11199999999, Elapsed Time: 8.261160
#
# Batch Size: 600
# Trial #: 0
# Inexact Objective: 11438.665999999994, Elapsed Time: 10.917715
# Trial #: 1
# Inexact Objective: 13905.325999999994, Elapsed Time: 9.945357
# Trial #: 2
# Inexact Objective: 12354.231999999985, Elapsed Time: 10.447970
# Trial #: 3
# Inexact Objective: 12224.18199999999, Elapsed Time: 11.044266
# Trial #: 4
# Inexact Objective: 11511.911999999978, Elapsed Time: 11.197753
# Trial #: 5
# Inexact Objective: 10545.526999999976, Elapsed Time: 1183.862651
# Trial #: 6
# Inexact Objective: 12075.655999999988, Elapsed Time: 10.874641
# Trial #: 7
# Inexact Objective: 12134.096999999983, Elapsed Time: 9.136961
# Trial #: 8
# Inexact Objective: 11282.946999999996, Elapsed Time: 8.640409
# Trial #: 9
# Inexact Objective: 12058.10199999998, Elapsed Time: 8.519315
# Trial #: 10
# Inexact Objective: 13133.965999999993, Elapsed Time: 9.032227
# Trial #: 11
# Inexact Objective: 11957.145999999993, Elapsed Time: 9.225269
# Trial #: 12
# Inexact Objective: 11753.821999999982, Elapsed Time: 8.793647
# Trial #: 13
# Inexact Objective: 11718.87699999999, Elapsed Time: 8.593884
# Trial #: 14
# Inexact Objective: 9753.015999999981, Elapsed Time: 8.774095
# Trial #: 15
# Inexact Objective: 14333.995999999985, Elapsed Time: 8.795850
# Trial #: 16
# Inexact Objective: 12201.55699999999, Elapsed Time: 9.087176
# Trial #: 17
# Inexact Objective: 11995.98599999999, Elapsed Time: 9.359570
# Trial #: 18
# Inexact Objective: 11619.316999999992, Elapsed Time: 9.572514
# Trial #: 19
# Inexact Objective: 11478.956999999991, Elapsed Time: 9.462857
# Trial #: 20
# Inexact Objective: 11340.075999999997, Elapsed Time: 9.690621
# Trial #: 21
# Inexact Objective: 12315.671999999988, Elapsed Time: 9.964070
# Trial #: 22
# Inexact Objective: 11641.661999999978, Elapsed Time: 9.505828
# Trial #: 23
# Inexact Objective: 10923.926999999978, Elapsed Time: 9.359455
# Trial #: 24
# Inexact Objective: 12189.82599999999, Elapsed Time: 9.370914
# Trial #: 25
# Inexact Objective: 10854.405999999988, Elapsed Time: 9.648735
# Trial #: 26
# Inexact Objective: 12577.655999999992, Elapsed Time: 9.779970
# Trial #: 27
# Inexact Objective: 12364.415999999987, Elapsed Time: 9.688744
# Trial #: 28
# Inexact Objective: 11954.14599999999, Elapsed Time: 9.487447
# Trial #: 29
# Inexact Objective: 12299.615999999987, Elapsed Time: 9.399444
# Trial #: 30
# Inexact Objective: 14920.661999999971, Elapsed Time: 9.822849
# Trial #: 31
# Inexact Objective: 10966.355999999996, Elapsed Time: 9.625889
# Trial #: 32
# Inexact Objective: 12064.966999999986, Elapsed Time: 9.477662
# Trial #: 33
# Inexact Objective: 11169.131999999987, Elapsed Time: 9.240346
# Trial #: 34
# Inexact Objective: 11782.065999999977, Elapsed Time: 9.471281
# Trial #: 35
# Inexact Objective: 12813.335999999992, Elapsed Time: 10.000917
# Trial #: 36
# Inexact Objective: 11004.591999999986, Elapsed Time: 9.798211
# Trial #: 37
# Inexact Objective: 11212.386999999992, Elapsed Time: 9.360328
# Trial #: 38
# Inexact Objective: 12105.365999999998, Elapsed Time: 9.303765
# Trial #: 39
# Inexact Objective: 12060.815999999995, Elapsed Time: 9.596665
# Trial #: 40
# Inexact Objective: 11499.05699999999, Elapsed Time: 9.876420
# Trial #: 41
# Inexact Objective: 11350.405999999999, Elapsed Time: 9.482689
# Trial #: 42
# Inexact Objective: 11164.396999999994, Elapsed Time: 9.576567
# Trial #: 43
# Inexact Objective: 11619.316999999992, Elapsed Time: 9.529773
# Trial #: 44
# Inexact Objective: 11978.775999999998, Elapsed Time: 9.744452
# Trial #: 45
# Inexact Objective: 11679.516, Elapsed Time: 9.797111
# Trial #: 46
# Inexact Objective: 11726.476999999995, Elapsed Time: 9.526364
# Trial #: 47
# Inexact Objective: 10969.88199999998, Elapsed Time: 9.467288
# Trial #: 48
# Inexact Objective: 11726.476999999995, Elapsed Time: 9.344558
# Trial #: 49
# Inexact Objective: 11695.471999999983, Elapsed Time: 9.813268
#
# Batch Size: 700
# Trial #: 0
# Inexact Objective: 15204.616999999987, Elapsed Time: 13.329762
# Trial #: 1
# Inexact Objective: 11692.942999999988, Elapsed Time: 13.034084
# Trial #: 2
# Inexact Objective: 13461.714999999997, Elapsed Time: 13.086248
# Trial #: 3
# Inexact Objective: 12990.121999999985, Elapsed Time: 13.536813
# Trial #: 4
# Inexact Objective: 12281.272, Elapsed Time: 12.998286
# Trial #: 5
# Inexact Objective: 15805.895999999997, Elapsed Time: 13.101358
# Trial #: 6
# Inexact Objective: 13574.536000000004, Elapsed Time: 13.735392
# Trial #: 7
# Inexact Objective: 14707.60199999998, Elapsed Time: 13.247284
# Trial #: 8
# Inexact Objective: 14215.211999999989, Elapsed Time: 13.184086
# Trial #: 9
# Inexact Objective: 13696.691999999985, Elapsed Time: 13.458780
# Trial #: 10
# Inexact Objective: 12933.295999999991, Elapsed Time: 13.506594
# Trial #: 11
# Inexact Objective: 13853.501999999982, Elapsed Time: 13.157608
# Trial #: 12
# Inexact Objective: 13431.195, Elapsed Time: 13.099213
# Trial #: 13
# Inexact Objective: 14384.46599999999, Elapsed Time: 13.642281
# Trial #: 14
# Inexact Objective: 13130.854999999989, Elapsed Time: 13.368827
# Trial #: 15
# Inexact Objective: 14929.48699999999, Elapsed Time: 13.285989
# Trial #: 16
# Inexact Objective: 11727.265999999992, Elapsed Time: 13.464919
# Trial #: 17
# Inexact Objective: 13201.725999999991, Elapsed Time: 13.511171
# Trial #: 18
# Inexact Objective: 13980.471999999998, Elapsed Time: 13.284795
# Trial #: 19
# Inexact Objective: 13566.641999999996, Elapsed Time: 13.540689
# Trial #: 20
# Inexact Objective: 15949.645999999997, Elapsed Time: 13.601142
# Trial #: 21
# Inexact Objective: 15008.511999999984, Elapsed Time: 12.974883
# Trial #: 22
# Inexact Objective: 13362.865999999998, Elapsed Time: 13.131427
# Trial #: 23
# Inexact Objective: 13479.851999999988, Elapsed Time: 13.648235
# Trial #: 24
# Inexact Objective: 14432.611999999997, Elapsed Time: 13.253214
# Trial #: 25
# Inexact Objective: 13546.481999999985, Elapsed Time: 12.959858
# Trial #: 26
# Inexact Objective: 14750.674999999988, Elapsed Time: 13.046794
# Trial #: 27
# Inexact Objective: 11422.563999999991, Elapsed Time: 13.038679
# Trial #: 28
# Inexact Objective: 14734.531999999981, Elapsed Time: 12.810261
# Trial #: 29
# Inexact Objective: 14369.936999999994, Elapsed Time: 12.830781
# Trial #: 30
# Inexact Objective: 14040.31199999998, Elapsed Time: 13.181677
# Trial #: 31
# Inexact Objective: 13318.275999999994, Elapsed Time: 12.881293
# Trial #: 32
# Inexact Objective: 13996.985999999994, Elapsed Time: 13.398341
# Trial #: 33
# Inexact Objective: 12918.207000000006, Elapsed Time: 12.894790
# Trial #: 34
# Inexact Objective: 12573.836000000003, Elapsed Time: 12.876698
# Trial #: 35
# Inexact Objective: 11422.563999999991, Elapsed Time: 12.905202
# Trial #: 36
# Inexact Objective: 14857.716999999986, Elapsed Time: 13.049206
# Trial #: 37
# Inexact Objective: 12216.14599999999, Elapsed Time: 13.165023
# Trial #: 38
# Inexact Objective: 13973.294999999991, Elapsed Time: 12.998762
# Trial #: 39
# Inexact Objective: 11794.624999999985, Elapsed Time: 12.974585
# Trial #: 40
# Inexact Objective: 12606.11199999999, Elapsed Time: 13.227689
# Trial #: 41
# Inexact Objective: 13973.354999999989, Elapsed Time: 13.134645
# Trial #: 42
# Inexact Objective: 15031.901999999984, Elapsed Time: 13.180663
# Trial #: 43
# Inexact Objective: 12171.627000000004, Elapsed Time: 13.067472
# Trial #: 44
# Inexact Objective: 14831.364999999983, Elapsed Time: 12.971255
# Trial #: 45
# Inexact Objective: 14992.374999999978, Elapsed Time: 12.969803
# Trial #: 46
# Inexact Objective: 13497.856999999993, Elapsed Time: 13.363874
# Trial #: 47
# Inexact Objective: 14808.726999999995, Elapsed Time: 13.887762
# Trial #: 48
# Inexact Objective: 13865.676999999985, Elapsed Time: 13.220970
# Trial #: 49
# Inexact Objective: 11422.563999999991, Elapsed Time: 13.302037
#
# Batch Size: 800
# Trial #: 0
# Inexact Objective: 19469.82499999999, Elapsed Time: 20.362514
# Trial #: 1
# Inexact Objective: 22452.082, Elapsed Time: 20.323587
# Trial #: 2
# Inexact Objective: 19870.482, Elapsed Time: 20.400775
# Trial #: 3
# Inexact Objective: 22777.826000000005, Elapsed Time: 20.701929
# Trial #: 4
# Inexact Objective: 20356.707000000006, Elapsed Time: 20.577967
# Trial #: 5
# Inexact Objective: 21158.065000000002, Elapsed Time: 20.716295
# Trial #: 6
# Inexact Objective: 20724.992000000002, Elapsed Time: 20.593444
# Trial #: 7
# Inexact Objective: 21556.897, Elapsed Time: 20.932728
# Trial #: 8
# Inexact Objective: 23474.542000000005, Elapsed Time: 20.659819
# Trial #: 9
# Inexact Objective: 24186.072000000004, Elapsed Time: 20.378452
# Trial #: 10
# Inexact Objective: 20787.375000000007, Elapsed Time: 20.624000
# Trial #: 11
# Inexact Objective: 20637.582000000006, Elapsed Time: 20.555039
# Trial #: 12
# Inexact Objective: 18961.512000000006, Elapsed Time: 20.226812
# Trial #: 13
# Inexact Objective: 21526.842, Elapsed Time: 20.898673
# Trial #: 14
# Inexact Objective: 21014.402, Elapsed Time: 20.658926
# Trial #: 15
# Inexact Objective: 22966.493000000006, Elapsed Time: 20.656028
# Trial #: 16
# Inexact Objective: 21592.657000000003, Elapsed Time: 20.683833
# Trial #: 17
# Inexact Objective: 19809.555000000015, Elapsed Time: 20.809627
# Trial #: 18
# Inexact Objective: 20630.642000000003, Elapsed Time: 20.669948
# Trial #: 19
# Inexact Objective: 23290.431999999997, Elapsed Time: 20.934377
# Trial #: 20
# Inexact Objective: 21427.897, Elapsed Time: 20.867569
# Trial #: 21
# Inexact Objective: 20489.76700000001, Elapsed Time: 20.523620
# Trial #: 22
# Inexact Objective: 19460.556000000004, Elapsed Time: 20.622583
# Trial #: 23
# Inexact Objective: 21405.652, Elapsed Time: 20.750350
# Trial #: 24
# Inexact Objective: 21040.857, Elapsed Time: 20.511961
# Trial #: 25
# Inexact Objective: 21159.56200000001, Elapsed Time: 20.800294
# Trial #: 26
# Inexact Objective: 20712.456000000017, Elapsed Time: 20.588266
# Trial #: 27
# Inexact Objective: 20033.122, Elapsed Time: 20.606711
# Trial #: 28
# Inexact Objective: 21314.987000000012, Elapsed Time: 20.513029
# Trial #: 29
# Inexact Objective: 20329.736999999997, Elapsed Time: 20.955510
# Trial #: 30
# Inexact Objective: 20662.546000000002, Elapsed Time: 20.753347
# Trial #: 31
# Inexact Objective: 21464.062, Elapsed Time: 20.724180
# Trial #: 32
# Inexact Objective: 21146.406999999996, Elapsed Time: 20.618052
# Trial #: 33
# Inexact Objective: 20808.657000000003, Elapsed Time: 20.974124
# Trial #: 34
# Inexact Objective: 20141.51700000001, Elapsed Time: 20.838838
# Trial #: 35
# Inexact Objective: 22090.421999999995, Elapsed Time: 20.944775
# Trial #: 36
# Inexact Objective: 21276.062, Elapsed Time: 21.080518
# Trial #: 37
# Inexact Objective: 19775.84699999999, Elapsed Time: 20.754206
# Trial #: 38
# Inexact Objective: 23248.842000000008, Elapsed Time: 21.038759
# Trial #: 39
# Inexact Objective: 22262.876999999997, Elapsed Time: 20.936250
# Trial #: 40
# Inexact Objective: 20113.96200000001, Elapsed Time: 20.782990
# Trial #: 41
# Inexact Objective: 20330.797000000002, Elapsed Time: 20.820616
# Trial #: 42
# Inexact Objective: 21192.986000000015, Elapsed Time: 20.743269
# Trial #: 43
# Inexact Objective: 23440.95600000001, Elapsed Time: 21.244193
# Trial #: 44
# Inexact Objective: 20229.972000000005, Elapsed Time: 20.832821
# Trial #: 45
# Inexact Objective: 20080.606000000007, Elapsed Time: 20.689167
# Trial #: 46
# Inexact Objective: 20914.962000000003, Elapsed Time: 20.529983
# Trial #: 47
# Inexact Objective: 22539.952, Elapsed Time: 20.979529
# Trial #: 48
# Inexact Objective: 20689.085, Elapsed Time: 20.487010
# Trial #: 49
# Inexact Objective: 21066.572000000004, Elapsed Time: 20.576873
#
# Batch Size: 900
# Trial #: 0
# Inexact Objective: 25638.875, Elapsed Time: 34.262819
# Trial #: 1
# Inexact Objective: 28553.335999999996, Elapsed Time: 33.942825
# Trial #: 2
# Inexact Objective: 28103.387000000006, Elapsed Time: 33.582235
# Trial #: 3
# Inexact Objective: 25532.337000000003, Elapsed Time: 34.169217
# Trial #: 4
# Inexact Objective: 25048.526000000016, Elapsed Time: 33.716768
# Trial #: 5
# Inexact Objective: 30386.775, Elapsed Time: 33.989404
# Trial #: 6
# Inexact Objective: 26524.074999999997, Elapsed Time: 34.013745
# Trial #: 7
# Inexact Objective: 25406.854999999996, Elapsed Time: 33.632107
# Trial #: 8
# Inexact Objective: 26724.672000000002, Elapsed Time: 33.196518
# Trial #: 9
# Inexact Objective: 26552.275999999998, Elapsed Time: 34.097529
# Trial #: 10
# Inexact Objective: 27067.00600000002, Elapsed Time: 33.345519
# Trial #: 11
# Inexact Objective: 25757.377000000004, Elapsed Time: 34.167914
# Trial #: 12
# Inexact Objective: 25757.887000000006, Elapsed Time: 33.971378
# Trial #: 13
# Inexact Objective: 25014.896000000008, Elapsed Time: 34.047664
# Trial #: 14
# Inexact Objective: 27022.065000000002, Elapsed Time: 33.470023
# Trial #: 15
# Inexact Objective: 28492.305999999997, Elapsed Time: 33.794871
# Trial #: 16
# Inexact Objective: 25233.351999999995, Elapsed Time: 33.914088
# Trial #: 17
# Inexact Objective: 28427.547000000017, Elapsed Time: 34.182216
# Trial #: 18
# Inexact Objective: 26963.836000000014, Elapsed Time: 33.528764
# Trial #: 19
# Inexact Objective: 25348.357000000007, Elapsed Time: 34.227094
# Trial #: 20
# Inexact Objective: 26452.464999999997, Elapsed Time: 33.936557
# Trial #: 21
# Inexact Objective: 27392.215000000004, Elapsed Time: 34.135250
# Trial #: 22
# Inexact Objective: 24700.85700000002, Elapsed Time: 34.055024
# Trial #: 23
# Inexact Objective: 25109.23600000001, Elapsed Time: 34.128869
# Trial #: 24
# Inexact Objective: 24426.49200000001, Elapsed Time: 33.833632
# Trial #: 25
# Inexact Objective: 25187.923000000006, Elapsed Time: 33.734134
# Trial #: 26
# Inexact Objective: 29476.772, Elapsed Time: 34.404570
# Trial #: 27
# Inexact Objective: 26524.074999999997, Elapsed Time: 33.621199
# Trial #: 28
# Inexact Objective: 25283.085, Elapsed Time: 34.491763
# Trial #: 29
# Inexact Objective: 25321.636000000013, Elapsed Time: 33.894899
# Trial #: 30
# Inexact Objective: 24964.22700000001, Elapsed Time: 34.476726
# Trial #: 31
# Inexact Objective: 27938.522999999997, Elapsed Time: 34.006126
# Trial #: 32
# Inexact Objective: 24784.58199999999, Elapsed Time: 33.916846
# Trial #: 33
# Inexact Objective: 24951.476000000002, Elapsed Time: 33.582707
# Trial #: 34
# Inexact Objective: 25085.986000000008, Elapsed Time: 34.163126
# Trial #: 35
# Inexact Objective: 25020.802, Elapsed Time: 33.895460
# Trial #: 36
# Inexact Objective: 26861.875999999997, Elapsed Time: 34.124993
# Trial #: 37
# Inexact Objective: 24475.475, Elapsed Time: 33.931218
# Trial #: 38
# Inexact Objective: 25531.516000000014, Elapsed Time: 34.488911
# Trial #: 39
# Inexact Objective: 24794.636000000017, Elapsed Time: 34.699149
# Trial #: 40
# Inexact Objective: 26520.886000000017, Elapsed Time: 34.245325
# Trial #: 41
# Inexact Objective: 24530.192999999996, Elapsed Time: 34.247233
# Trial #: 42
# Inexact Objective: 26769.57200000001, Elapsed Time: 34.078197
# Trial #: 43
# Inexact Objective: 27309.76600000002, Elapsed Time: 34.151208
# Trial #: 44
# Inexact Objective: 24114.927000000014, Elapsed Time: 34.126761
# Trial #: 45
# Inexact Objective: 28419.71499999999, Elapsed Time: 34.712274
# Trial #: 46
# Inexact Objective: 24288.35700000002, Elapsed Time: 35.123246
# Trial #: 47
# Inexact Objective: 26866.182000000004, Elapsed Time: 33.733394
# Trial #: 48
# Inexact Objective: 25187.923000000006, Elapsed Time: 34.221584
# Trial #: 49
# Inexact Objective: 26758.926000000018, Elapsed Time: 34.256031
#
# Batch Size: 1000
# Trial #: 0
# Inexact Objective: 31205.79199999999, Elapsed Time: 42.684058
# Trial #: 1
# Inexact Objective: 31858.027000000006, Elapsed Time: 46.153314
# Trial #: 2
# Inexact Objective: 31879.231999999993, Elapsed Time: 42.595012
# Trial #: 3
# Inexact Objective: 29676.826000000026, Elapsed Time: 42.636235
# Trial #: 4
# Inexact Objective: 32368.897, Elapsed Time: 43.197316
# Trial #: 5
# Inexact Objective: 29211.696000000004, Elapsed Time: 47.644348
# Trial #: 6
# Inexact Objective: 30889.897000000015, Elapsed Time: 43.590847
# Trial #: 7
# Inexact Objective: 30635.615000000005, Elapsed Time: 43.489014
# Trial #: 8
# Inexact Objective: 36370.383000000016, Elapsed Time: 42.503463
# Trial #: 9
# Inexact Objective: 31860.727000000003, Elapsed Time: 43.564567
# Trial #: 10
# Inexact Objective: 31223.09600000003, Elapsed Time: 46.153648
# Trial #: 11
# Inexact Objective: 30723.896, Elapsed Time: 43.136667
# Trial #: 12
# Inexact Objective: 29838.012999999995, Elapsed Time: 42.628174
# Trial #: 13
# Inexact Objective: 30782.897, Elapsed Time: 47.002640
# Trial #: 14
# Inexact Objective: 30180.806000000022, Elapsed Time: 42.781574
# Trial #: 15
# Inexact Objective: 30382.087000000003, Elapsed Time: 42.920068
# Trial #: 16
# Inexact Objective: 31828.216000000015, Elapsed Time: 43.653488
# Trial #: 17
# Inexact Objective: 30767.696000000004, Elapsed Time: 46.084002
# Trial #: 18
# Inexact Objective: 30517.435000000005, Elapsed Time: 42.437309
# Trial #: 19
# Inexact Objective: 31572.97300000001, Elapsed Time: 43.225400
# Trial #: 20
# Inexact Objective: 31591.867000000002, Elapsed Time: 43.207323
# Trial #: 21
# Inexact Objective: 29653.213000000007, Elapsed Time: 46.894454
# Trial #: 22
# Inexact Objective: 30870.017000000003, Elapsed Time: 42.739147
# Trial #: 23
# Inexact Objective: 31766.22700000001, Elapsed Time: 42.602402
# Trial #: 24
# Inexact Objective: 30712.202, Elapsed Time: 42.722868
# Trial #: 25
# Inexact Objective: 30227.08200000002, Elapsed Time: 44.870014
# Trial #: 26
# Inexact Objective: 32801.59500000001, Elapsed Time: 46.969745
# Trial #: 27
# Inexact Objective: 30809.81500000001, Elapsed Time: 44.020567
# Trial #: 28
# Inexact Objective: 30454.72200000002, Elapsed Time: 42.864166
# Trial #: 29
# Inexact Objective: 29106.063, Elapsed Time: 45.043872
# Trial #: 30
# Inexact Objective: 30497.235, Elapsed Time: 45.089544
# Trial #: 31
# Inexact Objective: 32101.665000000008, Elapsed Time: 42.661731
# Trial #: 32
# Inexact Objective: 34075.576000000015, Elapsed Time: 43.567627
# Trial #: 33
# Inexact Objective: 30758.99600000001, Elapsed Time: 48.444711
# Trial #: 34
# Inexact Objective: 29282.056000000004, Elapsed Time: 42.902625
# Trial #: 35
# Inexact Objective: 29148.462999999992, Elapsed Time: 43.935857
# Trial #: 36
# Inexact Objective: 30685.425000000003, Elapsed Time: 44.063154
# Trial #: 37
# Inexact Objective: 30359.172000000002, Elapsed Time: 42.909182
# Trial #: 38
# Inexact Objective: 32828.74600000001, Elapsed Time: 44.912373
# Trial #: 39
# Inexact Objective: 29726.497000000014, Elapsed Time: 43.422254
# Trial #: 40
# Inexact Objective: 31046.247000000007, Elapsed Time: 45.831878
# Trial #: 41
# Inexact Objective: 31122.327, Elapsed Time: 43.565245
# Trial #: 42
# Inexact Objective: 30024.98700000002, Elapsed Time: 46.233715
# Trial #: 43
# Inexact Objective: 32097.59300000001, Elapsed Time: 41.907538
# Trial #: 44
# Inexact Objective: 31028.253000000008, Elapsed Time: 41.210290
# Trial #: 45
# Inexact Objective: 33669.455, Elapsed Time: 45.469053
# Trial #: 46
# Inexact Objective: 30129.142000000003, Elapsed Time: 40.696932
# Trial #: 47
# Inexact Objective: 33274.305, Elapsed Time: 45.617422
# Trial #: 48
# Inexact Objective: 31056.082000000006, Elapsed Time: 41.198581
# Trial #: 49
# Inexact Objective: 31157.59600000001, Elapsed Time: 41.798263
#
# Batch Size: 1100
# Trial #: 0
# Inexact Objective: 37553.36200000001, Elapsed Time: 61.255842
# Trial #: 1
# Inexact Objective: 39947.31699999998, Elapsed Time: 57.965250
# Trial #: 2
# Inexact Objective: 39308.59499999997, Elapsed Time: 64.404196
# Trial #: 3
# Inexact Objective: 39995.981999999975, Elapsed Time: 58.933022
# Trial #: 4
# Inexact Objective: 40004.08199999998, Elapsed Time: 62.601040
# Trial #: 5
# Inexact Objective: 38329.115999999995, Elapsed Time: 57.836221
# Trial #: 6
# Inexact Objective: 38184.341999999975, Elapsed Time: 64.060704
# Trial #: 7
# Inexact Objective: 39294.64600000002, Elapsed Time: 59.069677
# Trial #: 8
# Inexact Objective: 38252.787, Elapsed Time: 58.684062
# Trial #: 9
# Inexact Objective: 40049.62300000002, Elapsed Time: 63.123951
# Trial #: 10
# Inexact Objective: 39867.856, Elapsed Time: 58.543807
# Trial #: 11
# Inexact Objective: 38077.88600000001, Elapsed Time: 61.624405
# Trial #: 12
# Inexact Objective: 37592.277, Elapsed Time: 61.585174
# Trial #: 13
# Inexact Objective: 38305.417, Elapsed Time: 58.262301
# Trial #: 14
# Inexact Objective: 36646.206000000006, Elapsed Time: 66.553030
# Trial #: 15
# Inexact Objective: 40984.34199999999, Elapsed Time: 59.479430
# Trial #: 16
# Inexact Objective: 37383.185999999994, Elapsed Time: 60.629735
# Trial #: 17
# Inexact Objective: 37301.916000000005, Elapsed Time: 62.401882
# Trial #: 18
# Inexact Objective: 37452.822, Elapsed Time: 59.343893
# Trial #: 19
# Inexact Objective: 37136.43599999998, Elapsed Time: 65.337576
# Trial #: 20
# Inexact Objective: 37129.887, Elapsed Time: 57.904326
# Trial #: 21
# Inexact Objective: 41524.132, Elapsed Time: 61.591797
# Trial #: 22
# Inexact Objective: 40703.12699999999, Elapsed Time: 63.450536
# Trial #: 23
# Inexact Objective: 42164.306, Elapsed Time: 58.666847
# Trial #: 24
# Inexact Objective: 38425.962, Elapsed Time: 61.650623
# Trial #: 25
# Inexact Objective: 35675.092000000004, Elapsed Time: 61.740597
# Trial #: 26
# Inexact Objective: 36346.28600000002, Elapsed Time: 59.369997
# Trial #: 27
# Inexact Objective: 35639.126000000004, Elapsed Time: 64.211002
# Trial #: 28
# Inexact Objective: 38373.79199999997, Elapsed Time: 58.140843
# Trial #: 29
# Inexact Objective: 37052.06300000001, Elapsed Time: 62.744471
# Trial #: 30
# Inexact Objective: 39391.786, Elapsed Time: 65.177509
# Trial #: 31
# Inexact Objective: 38047.523000000016, Elapsed Time: 56.620907
# Trial #: 32
# Inexact Objective: 39220.26699999999, Elapsed Time: 64.032385
# Trial #: 33
# Inexact Objective: 38449.507, Elapsed Time: 61.906918
# Trial #: 34
# Inexact Objective: 35952.76600000001, Elapsed Time: 59.659649
# Trial #: 35
# Inexact Objective: 37158.21599999999, Elapsed Time: 63.421293
# Trial #: 36
# Inexact Objective: 39601.88199999998, Elapsed Time: 60.726319
# Trial #: 37
# Inexact Objective: 38176.645000000004, Elapsed Time: 59.961013
# Trial #: 38
# Inexact Objective: 38826.947, Elapsed Time: 65.788812
# Trial #: 39
# Inexact Objective: 40866.94199999998, Elapsed Time: 62.237188
# Trial #: 40
# Inexact Objective: 38549.09599999998, Elapsed Time: 59.673018
# Trial #: 41
# Inexact Objective: 37260.20199999999, Elapsed Time: 62.507428
# Trial #: 42
# Inexact Objective: 40991.27199999997, Elapsed Time: 59.301394
# Trial #: 43
# Inexact Objective: 38144.175999999985, Elapsed Time: 63.373636
# Trial #: 44
# Inexact Objective: 40836.116999999984, Elapsed Time: 63.688311
# Trial #: 45
# Inexact Objective: 36587.557, Elapsed Time: 57.969433
# Trial #: 46
# Inexact Objective: 36873.566999999995, Elapsed Time: 63.707217
# Trial #: 47
# Inexact Objective: 36319.556000000004, Elapsed Time: 58.202486
# Trial #: 48
# Inexact Objective: 38234.785999999986, Elapsed Time: 62.502328
# Trial #: 49
# Inexact Objective: 37459.02599999999, Elapsed Time: 62.700435

# %%
inexact_list = [x / 1000 for x in pdac_inexact]

greedy_list = [x / 1000 for x in pdac_greedy]

naive_list = [x / 1000 for x in pdac_naive]

# %% [markdown]
# # Plot the Results
# Use the results from the previous cell to plot the PDAC over different batch sizes for each of the three algorithms

# %% [markdown]
# - BW Graph

# %%
fig, ax = plt.subplots(figsize=(16,9))

# Plot data
job_graph_xvalues = [i for i in range(start_size, end_size, step_size)]
ax.plot(job_graph_xvalues, inexact_list, label="Randomized Rounding LP", linestyle='-', color = 'black', linewidth=3)
# ax.plot(job_graph_xvalues, greedy_list, label="Greedy", linestyle='--', color = 'black', linewidth=3)
# ax.plot(job_graph_xvalues, naive_list, label="Naive", linestyle=':', color = 'black', linewidth=3)

ax.grid(True, linestyle='--', linewidth=0.25, color='black')
plt.tick_params(axis='both', labelsize=14)
ax.set_xticks(np.arange(start_size, end_size, step_size))
ax.set_yticks(np.arange(0, max(naive_list)+10, 10))

ax.set_title("Algorithm Comparison by Batch Size", fontsize=36, fontname="Georgia", color='black')
ax.set_xlabel("Job Batch Size", fontsize=24, fontname='Verdana', color='black')
ax.set_ylabel("Peak Demand Above \n Curve (kWh)", fontsize=24, fontname='Verdana', color='black')
ax.legend(loc='upper left', prop={'family': 'Verdana', 'size': 14})

# Save the figure to the Figures folder
plt.savefig(f"../../Output_Data/Final_Figures/inexact_pdac_analysis_{analysis_num}_bw.png")
plt.show()

# %% [markdown]
# - Color Graph

# %%
fig, ax = plt.subplots(figsize=(16,9))

# Set figure (outside) background
# fig.patch.set_facecolor("#FFFFFF")

# Set axes (plot area) background
# ax.set_facecolor("#FFFFFF")

# Plot data
job_graph_xvalues = [i for i in range(start_size, end_size, step_size)]
ax.plot(job_graph_xvalues, inexact_list, label="Randomized Rounding LP", linestyle='-', color = '#f77f00', linewidth=5)
# ax.plot(job_graph_xvalues, greedy_list, label="Greedy", linestyle='--', color = '#0081a7', linewidth=5)
# ax.plot(job_graph_xvalues, naive_list, label="Naive", linestyle=':', color = '#9448bc', linewidth=5)

ax.grid(True, linestyle='--', linewidth=0.25, color='black')
plt.tick_params(axis='both', labelsize=14)
ax.set_xticks(np.arange(start_size, end_size, step_size))
ax.set_yticks(np.arange(0, max(naive_list)+10, 10))

ax.set_title("Relaxed LP Performance Analysis", fontsize=36, fontname="Georgia", color='black')
ax.set_xlabel("Job Batch Size", fontsize=24, fontname='Verdana', color='black')
ax.set_ylabel("Peak Demand Above \n Curve (kWh)", fontsize=24, fontname='Verdana', color='black')
ax.legend(loc='upper left', prop={'family': 'Verdana', 'size': 14})

ax.tick_params(colors='black')
for spine in ax.spines.values():
    spine.set_edgecolor('black')

# Save the figure to the Figures folder
plt.savefig(f"../../Output_Data/Final_Figures/inexact_pdac_analysis_{analysis_num}_color.png")
plt.show()

# %% [markdown]
# # Export Data
# Export the analyzed data so that it can be archived for future use.

# %%
folder_path= "../../Output_Data/Final_PDAC_Results"
os.makedirs(folder_path, exist_ok=True)

# %%
# Write to a data csv file
with open(f"{folder_path}/rr_self_analysis_{analysis_num}.csv", "a", newline="") as csvfile:
    fieldnames = ['batch size', 'trial #', 'Rand_Round', 'Rand_Round Time']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # Only write the header on the very first trial run
    writer.writeheader()
    writer.writerows(final_data)

    csvfile.close()
